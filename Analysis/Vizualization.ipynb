# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### DFT RDF Calculation

# %%
rdf_OO_dft = np.loadtxt('dft/'+'rdf_OO.out')
plt.figure(figsize=(8, 3.4))
plt.xlim(0, 6)
plt.ylim(0, 3.5)
plt.xlabel("$r/\mathrm{\AA}$", fontsize=14)
plt.ylabel("$g_{\mathrm{OO}}(r)$", fontsize=14)
plt.xticks(np.arange(0, 7, 1))
plt.plot(rdf_OO_dft[:, 0], rdf_OO_dft[:, 1], color = "purple", label="ice")

plt.legend(fontsize=14)
plt.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
plt.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
plt.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
plt.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
plt.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
plt.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")

# %%
rdf_OO_dft = np.loadtxt('dft/'+'rdf_OO.out')
fig = plt.figure(figsize=(8,4.4),dpi=100)
ax_1 = fig.add_subplot(211)
ax_1.set_xlim([0, 6])
ax_1.set_ylim([0, 3.4])
ax_1.set_xticks(np.arange(0, 7, 1))
ax_1.set_ylabel("$g_{\mathrm{OO}}(r)$", fontsize=14)
ax_1.set_xlabel("$r/\mathrm{\AA}$", fontsize=14)
#ax_1.legend(fontsize=14)
ax_1.plot(rdf_OO_dft[:, 0], rdf_OO_dft[:, 1], color = "darkorange", label="ice")
ax_1.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
ax_1.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
ax_1.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
ax_1.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
ax_1.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
ax_1.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")

# plt.tight_layout(pad=1.0)
plt.savefig('rdf_subplot.png',bbox_inches = 'tight')

# %%
rdf_OH_dft = np.loadtxt('dft/' + 'rdf_OH.out')
plt.figure(figsize=(8, 3.4))
plt.xlim(0, 6)
plt.ylim(0, 3.5)
plt.xlabel("$r/\mathrm{\AA}$", fontsize=14)
plt.ylabel("$g_{\mathrm{OH}}(r)$", fontsize=14)
plt.xticks(np.arange(0, 7, 1))
plt.plot(rdf_OH_dft[:, 0], rdf_OH_dft[:, 1], color = "purple", label="ice")

plt.legend(fontsize=14)
plt.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
plt.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
plt.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
plt.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
plt.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
plt.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")

# %%
rdf_HH_dft = np.loadtxt('dft/' + 'rdf_HH.out')
plt.figure(figsize=(8, 3.4))
plt.xlim(0, 6)
plt.ylim(0, 3.5)
plt.xlabel("$r/\mathrm{\AA}$", fontsize=14)
plt.ylabel("$g_{\mathrm{HH}}(r)$", fontsize=14)
plt.xticks(np.arange(0, 7, 1))
plt.plot(rdf_HH_dft[:, 0], rdf_HH_dft[:, 1], color = "purple", label="ice")

plt.legend(fontsize=14)
plt.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
plt.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
plt.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
plt.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
plt.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
plt.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")

# %% [markdown]
# ### DeepMD RDF Calculation

# %%
rdf = []
Nbin = 100
Nsamp = 1001
with open("ice_pimd.rdf", "r") as f:
    for i in range(3):
        f.readline()
    for i in range(Nsamp):
        f.readline()
        for j in range(Nbin):
            rdf.append(f.readline().split())
rdf_dpmd = np.array(rdf, dtype = "float").reshape(Nsamp, Nbin, 8)
rdf_dpmd_mean = rdf_dpmd[:].mean(axis=0)

# %%
plt.figure(figsize=(8, 3.4))
plt.xlim(0, 6)
plt.ylim(0, 3.5)
plt.xlabel("$r/\mathrm{\AA}$", fontsize=14)
plt.ylabel("$g_{\mathrm{OO}}(r)$", fontsize=14)
plt.xticks(np.arange(0, 7, 1))
plt.plot(rdf_dpmd_mean[:, 1], rdf_dpmd_mean[:, 2], color = "blue", label="ice")

plt.legend(fontsize=14)
plt.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
plt.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
plt.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
plt.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
plt.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
plt.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")

# %%
#DFT data loading
rdf_OO_dft = np.loadtxt('dft/'+'rdf_OO.out')
rdf_OH_dft = np.loadtxt('dft/' + 'rdf_OH.out')
rdf_HH_dft = np.loadtxt('dft/' + 'rdf_HH.out')

fig = plt.figure(figsize=(8,4.4),dpi=100)
ax_1 = fig.add_subplot(311)
ax_1.set_xlim([0, 6])
ax_1.set_ylim([0, 4.4])
ax_1.set_xticks(np.arange(0, 7, 1))
#O-O
ax_1.set_ylabel("$g_{\mathrm{OO}}(r)$", fontsize=14)
ax_1.plot(rdf_OO_dft[:, 0], rdf_OO_dft[:, 1], color = "deepskyblue", label="DFT O-O")
ax_1.plot(rdf_dpmd_mean[:, 1], rdf_dpmd_mean[:, 2], color = "deepskyblue",linestyle = "--", label="DeePMD O-O")
ax_1.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
ax_1.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
ax_1.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
ax_1.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
ax_1.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
ax_1.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")
ax_1.legend()

#O-H
ax_2 = fig.add_subplot(312)
ax_2.set_xlim([0, 6])
ax_2.set_ylim([0, 4.4])
ax_2.set_xticks(np.arange(0, 7, 1))
ax_2.set_ylabel("$g_{\mathrm{OH}}(r)$", fontsize=14)
# ax_1.set_xlabel("$r/\mathrm{\AA}$", fontsize=14)
ax_2.plot(rdf_OH_dft[:, 0], rdf_OH_dft[:, 1], color = "seagreen", label="DFT O-H")
ax_2.plot(rdf_dpmd_mean[:, 1], rdf_dpmd_mean[:, 4], color = "seagreen",linestyle = "--", label="DeePMD O-H")
ax_2.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
ax_2.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
ax_2.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
ax_2.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
ax_2.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
ax_2.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")
ax_2.legend()

#H-H
ax_3 = fig.add_subplot(313)
ax_3.set_xlim([0, 6])
ax_3.set_ylim([0, 4.4])
ax_3.set_xticks(np.arange(0, 7, 1))
ax_3.set_ylabel("$g_{\mathrm{OH}}(r)$", fontsize=14)

ax_3.plot(rdf_OH_dft[:, 0], rdf_OH_dft[:, 1], color = "salmon", label="DFT H-H")
ax_3.plot(rdf_dpmd_mean[:, 1], rdf_dpmd_mean[:, 6], color = "salmon",linestyle = "--", label="DeePMD H-H")
ax_3.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
ax_3.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
ax_3.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
ax_3.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
ax_3.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
ax_3.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")
ax_3.set_xlabel("$r/\mathrm{\AA}$", fontsize=14)
ax_3.legend()
plt.tight_layout(pad=1.0)
plt.savefig('rdf_subplot.png',bbox_inches = 'tight')

# %%
plt.figure(figsize=(8, 3.4))
plt.xlim(0, 6)
plt.ylim(0, 3.5)
plt.xlabel("$r/\mathrm{\AA}$", fontsize=14)
plt.ylabel("$g_{\mathrm{OH}}(r)$", fontsize=14)
plt.xticks(np.arange(0, 7, 1))
plt.plot(rdf_dpmd_mean[:, 1], rdf_dpmd_mean[:, 4], color = "blue", label="ice")

plt.legend(fontsize=14)
plt.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
plt.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
plt.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
plt.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
plt.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
plt.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")

# %%
plt.figure(figsize=(8, 3.4))
plt.xlim(0, 6)
plt.ylim(0, 3.5)
plt.xlabel("$r/\mathrm{\AA}$", fontsize=14)
plt.ylabel("$g_{\mathrm{HH}}(r)$", fontsize=14)
plt.xticks(np.arange(0, 7, 1))
plt.plot(rdf_dpmd_mean[:, 1], rdf_dpmd_mean[:, 6], color = "blue", label="ice")

plt.legend(fontsize=14)
plt.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
plt.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
plt.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
plt.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
plt.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
plt.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")

# %% [markdown]
# ### Comparison

# %%
plt.figure(figsize=(10,6.4),dpi=100)
plt.style.use('ggplot')
plt.xlim(0, 6)
plt.ylim(0, 3.5)
plt.xlabel("$r/\mathrm{\AA}$", fontsize=14)
plt.ylabel("$g_(r)$", fontsize=14)
plt.xticks(np.arange(0, 7, 1))
plt.plot(rdf_dpmd_mean[:, 1], rdf_dpmd_mean[:, 2], color = "green", label="DeePMD O-O ")
plt.plot(rdf_dpmd_mean[:, 1], rdf_dpmd_mean[:, 6], color = "blue", label="DeePMD H-H")
plt.plot(rdf_dpmd_mean[:, 1], rdf_dpmd_mean[:, 4], color = "red", label="DeePMD O-H")
plt.plot(rdf_OO_dft[:, 0], rdf_OO_dft[:, 1], color = "green",linestyle = "--", label="DFT O-O")
plt.plot(rdf_OH_dft[:, 0], rdf_OH_dft[:, 1], color = "red", linestyle = "--",label="DFT O-H")
plt.plot(rdf_HH_dft[:, 0], rdf_HH_dft[:, 1], color = "blue", linestyle = "--",label="DFT H-H")

plt.legend(fontsize=14,loc='upper right')
plt.plot([0, 6], [0.5, 0.5], linestyle = "--", color = "black")
plt.plot([0, 6], [1.0, 1.0], linestyle = "--", color = "black")
plt.plot([0, 6], [1.5, 1.5], linestyle = "--", color = "black")
plt.plot([0, 6], [2.0, 2.0], linestyle = "--", color = "black")
plt.plot([0, 6], [2.5, 2.5], linestyle = "--", color = "black")
plt.plot([0, 6], [3.0, 3.0], linestyle = "--", color = "black")

plt.savefig('rdf.png')
